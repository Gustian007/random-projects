# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"D:\credit card dataset\creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Distribusi kelas fraud dan non-fraud
print("\nDistribusi Kelas:")
print(df['Class'].value_counts())
# Out:
# Distribusi Kelas:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# Data Imbalance

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Class', data=df)
plt.title('Distribusi Kelas Fraud dan Non-Fraud')
plt.xlabel('Class (0 = Non-Fraud, 1 = Fraud)')
plt.ylabel('Jumlah Sample')
plt.show()

# %%
# Perbandingan persentase kelas
fraud_ratio = df['Class'].value_counts(normalize=True)[1]
print(f"Persentase Fraud: {fraud_ratio*100:.4f}%")
# Out:
# Persentase Fraud: 0.1727%

# %%
# Visualisasi korelasi antar fitur
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap Korelasi Fitur')
plt.show()

# %%
# Visualisasi distribusi beberapa fitur penting (misal 'Amount')
plt.figure(figsize=(8,4))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Distribusi Feature Amount')
plt.show()

# %%
# Visualisasi distribusi Amount berdasarkan kelas fraud dan non-fraud
plt.figure(figsize=(8,4))
sns.boxplot(x='Class', y='Amount', data=df)
plt.title('Distribusi Amount berdasarkan Kelas')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Log transformasi Amount (log1p agar aman untuk 0)
df['Amount_log'] = np.log1p(df['Amount'])

# %%
# Normalisasi (standarisasi) pada kolom Amount_log
scaler = StandardScaler()
df['Amount_log_scaled'] = scaler.fit_transform(df[['Amount_log']])

# %%
print(df[['Amount', 'Amount_log', 'Amount_log_scaled']].head())
# Out:
#    Amount  Amount_log  Amount_log_scaled
# 0  149.62    5.014760           1.124303
# 1    2.69    1.305626          -1.114639
# 2  378.66    5.939276           1.682368
# 3  123.50    4.824306           1.009339
# 4   69.99    4.262539           0.670241

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Original Amount')

plt.subplot(1,3,2)
sns.histplot(df['Amount_log'], bins=50, kde=True)
plt.title('Log-transformed Amount')

plt.subplot(1,3,3)
sns.histplot(df['Amount_log_scaled'], bins=50, kde=True)
plt.title('Log Amount (Scaled)')

plt.show()

# %%
print(df[['Amount_log', 'Amount_log_scaled']].describe())
# Out:
#           Amount_log  Amount_log_scaled
# count  284807.000000       2.848070e+05
# mean        3.152188       9.101110e-17
# std         1.656648       1.000002e+00
# min         0.000000      -1.902754e+00
# 25%         1.887070      -7.636627e-01
# 50%         3.135494      -1.007690e-02
# 75%         4.358822       7.283598e-01
# max        10.153941       4.226464e+00

# %%
from sklearn.model_selection import train_test_split

# %%
# Pilih semua fitur kecuali kolom target dan kolom asli 'Amount'
X = df.drop(['Class', 'Amount', 'Amount_log'], axis=1)  
y = df['Class']

# Split data, stratify supaya distribusi kelas tetap seimbang
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

print("Sebelum SMOTE:", y_train.value_counts())
print("Setelah SMOTE:", y_train_res.value_counts())
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Sebelum SMOTE: Class
# 0    199020
# 1       344
# Name: count, dtype: int64
# Setelah SMOTE: Class
# 0    199020
# 1    199020
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

model = RandomForestClassifier(random_state=42)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))

# AUC ROC
y_prob = model.predict_proba(X_test)[:,1]
print("ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.86      0.78      0.82       148
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.89      0.91     85443
# weighted avg       1.00      1.00      1.00     85443
#
# ROC AUC: 0.9528613334009313

# %%
from sklearn.metrics import confusion_matrix

# %%
# Hitung confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Tampilkan matrix
print("Confusion Matrix:")
print(cm)

# Visualisasi confusion matrix
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Non-Fraud', 'Predicted Fraud'],
            yticklabels=['Actual Non-Fraud', 'Actual Fraud'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[85276    19]
#  [   32   116]]

# %%
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Time               284807 non-null  float64
#  1   V1                 284807 non-null  float64
#  2   V2                 284807 non-null  float64
#  3   V3                 284807 non-null  float64
#  4   V4                 284807 non-null  float64
#  5   V5                 284807 non-null  float64
#  6   V6                 284807 non-null  float64
#  7   V7                 284807 non-null  float64
#  8   V8                 284807 non-null  float64
#  9   V9                 284807 non-null  float64
#  10  V10                284807 non-null  float64
#  11  V11                284807 non-null  float64
#  12  V12                284807 non-null  float64
#  13  V13                284807 non-null  float64
#  14  V14                284807 non-null  float64
# ...
